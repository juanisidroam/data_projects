# %%
import matplotlib as plt
import pandas as pd

# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe(include="all")
# Out:
#               Rank   Major_code                              Major  \
# count   173.000000   173.000000                                173
# unique         NaN          NaN                                173
# top            NaN          NaN  INTERDISCIPLINARY SOCIAL SCIENCES
# freq           NaN          NaN                                  1
# mean     87.000000  3879.815029                                NaN
# std      50.084928  1687.753140                                NaN
# min       1.000000  1100.000000                                NaN
# 25%      44.000000  2403.000000                                NaN
# 50%      87.000000  3608.000000                                NaN
# 75%     130.000000  5503.000000                                NaN
# max     173.000000  6403.000000                                NaN
#
#                 Total            Men          Women Major_category  \
# count      172.000000     172.000000     172.000000            173
# ...

# %% [markdown]
# Here we find the rows with NaN and prceedo to drop them.

# %%
len(recent_grads)
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()

# %%
len(recent_grads)
# Out:
# 172

# %% [markdown]
# Now we'll try to plot the data in different ways.

# %%
recent_grads.plot(x="Sample_size", y="Median", kind="scatter", title="Median vs. Sample Size", figsize=(5,5))

# %% [markdown]
# Here we see that the most popular majors, orbit around 35,000K a year. There seems to be a negative correlation between most popular major and average income, at least after a certain point. Seems to be that popularity of major increases income until the 35-50K range, then it starts to decrease.
#
# So it seems there's a type of major that doesn't attract people and doesn't pay, but there's another type that doesn't attract people and pays a lot. Maybe it's related to the difficulty of said majors as you'd expect the most profitable ones to be the most popular ones.

# %%
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="scatter", title="Unemployment vs. Sample Size", figsize=(5,5))

# %%
recent_grads.plot(x="Full_time", y="Median", kind="scatter", title="Full Time vs. Median", figsize=(5,5))

# %% [markdown]
# Like wise, there seems to be a negative relation with amount of employees and median salary. May be related to the "popular major vs median salary" situation.

# %%
recent_grads.plot(x="Men", y="Median", kind="scatter", title="Men vs. Median", figsize=(5,5))

# %%
recent_grads.plot(x="Women", y="Median", kind="scatter", title="Women vs. Median", figsize=(5,5))

# %% [markdown]
# In the majority women subjects, students take to make the least money.

# %%
recent_grads["Sample_size"].hist(bins=20, range=(0,500), color="LightBlue")

# %% [markdown]
# If we look at **Sample Size**, the high majority of majors have less than 500 students. With onl a few going above 2,000. Interesting that there's a single one above 4,000.

# %%
recent_grads["Median"].hist(bins=10, color="LightGreen")

# %% [markdown]
# Most **Median Salaries** are between 30-50K, with only one going above 100K.

# %%
recent_grads["Employed"].hist(bins=10, range=(0,50000), color="LightBlue")

# %%
recent_grads["Full_time"].hist(bins=10, range=(0,50000), color="LightBlue")

# %%
recent_grads["Unemployment_rate"].hist(bins=10, color="LightBlue")

# %%
recent_grads["ShareWomen"].hist(bins=2,color="LightBlue")

# %% [markdown]
# Most majors have a **Share of Women** between 0.2-0.8. Around 40% of majors are predominantly male, and 60% are predominantly female.

# %%
recent_grads["Men"].hist(bins=5, range=(0,10000), color="LightBlue")

# %%
recent_grads["Women"].hist(bins=5, range=(0,10000), color="LightBlue")

# %%
from pandas.plotting import scatter_matrix as sct

# %%
sct(recent_grads[["Women", "Men"]], figsize=(10,10), color="Green", hist_kwds={'color':['burlywood']})
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb99b96a940>,
# ...
#       dtype=object)

# %%
sct(recent_grads[["Sample_size", "Median"]], figsize=(10,10), color="Green", hist_kwds={'color':['burlywood']})
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb99b69dcf8>,
# ...
#       dtype=object)

# %%
sct(recent_grads[["Sample_size", "Median", "Unemployment_rate"]], figsize=(10,10), color="Green", hist_kwds={'color':['burlywood']})
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb99b5d8da0>,
# ...
#       dtype=object)

# %%
sct(recent_grads[["ShareWomen", "Median"]], figsize=(10,10), color="Green", hist_kwds={'color':['burlywood']})
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb99b194c50>,
# ...
#       dtype=object)

# %% [markdown]
# Seems that the more male-skewed majors are, the higher the median salary.

# %%
recent_grads[:5]["Women"].plot(kind="bar")

# %%
recent_grads[:5].plot.bar(x="Major", y="Women")

# %%
first_last = recent_grads[:10]
first_last = first_last.append(recent_grads[-10:])
first_last.plot.bar(x="Major", y="ShareWomen")

# %%
first_last.plot.bar(x="Major", y="Unemployment_rate")

# %%
majorcat_women = {}
majorcat_men = {}
for a in range(len(recent_grads)):
    major = recent_grads.iloc[a]["Major_category"]
    if major in majorcat_women:
        majorcat_women[major] += recent_grads.iloc[a]["Women"]
    else:
        majorcat_women[major] = recent_grads.iloc[a]["Women"]
    if major in majorcat_men:
        majorcat_men[major] += recent_grads.iloc[a]["Men"]
    else:
        majorcat_men[major] = recent_grads.iloc[a]["Men"]

# %%
cat_men_women = pd.DataFrame([majorcat_women, majorcat_men]).T

# %%
cat_men_women.columns = ["Women", "Men"]

# %%
cat_men_women
# Out:
#                                         Women       Men
# Agriculture & Natural Resources       35263.0   40357.0
# Arts                                 222740.0  134390.0
# Biology & Life Science               268943.0  184919.0
# Business                             634524.0  667852.0
# Communications & Journalism          260680.0  131921.0
# Computers & Mathematics               90283.0  208725.0
# Education                            455603.0  103526.0
# Engineering                          129276.0  408307.0
# Health                               387713.0   75517.0
# Humanities & Liberal Arts            440622.0  272846.0
# Industrial Arts & Consumer Services  126011.0  103781.0
# Interdisciplinary                      9479.0    2817.0
# Law & Public Policy                   87978.0   91129.0
# Physical Sciences                     90089.0   95390.0
# Psychology & Social Work             382892.0   98115.0
# Social Science                       273132.0  256834.0

# %%
cat_men_women.plot.bar(figsize = (10,5), width=0.8,color=["Red", "Blue"], alpha=0.5, edgecolor=None)

# %%
recent_grads.boxplot("Median")

# %%
recent_grads.boxplot(["Unemployment_rate"])

# %%
recent_grads.plot(x="Sample_size", y="Median", kind="hexbin", title="Median vs. Sample Size", figsize=(10,8), gridsize = 25)

# %%
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="hexbin", title="Unemployment vs. Sample Size", figsize=(10,8), gridsize = 25)
