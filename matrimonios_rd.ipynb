# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
# %matplotlib inline

# %%
matri = pd.read_csv("matrimonios_rd.csv")
# matri = matri.drop("Unnamed: 0", axis=1)
# matri = matri.reindex(sorted(matri.columns), axis=1)
matri
# Out:
#     Género               Edad   2001   2002   2003   2004   2005   2006  \
# 0    Mujer                15-      0      0      0      0      0      0
# 1    Mujer              15-19   3181   2718   2527   2351   2249   2406
# 2    Mujer              20-24   9054   8555   8622   8632   8403   8978
# 3    Mujer              25-29   8570   8444   8306   8411   8752   9733
# 4    Mujer              30-34   6030   5966   6298   6447   6833   7187
# 5    Mujer              35-39   3796   3964   4077   4351   4364   4699
# 6    Mujer              40-44   2478   2605   2713   3052   2915   3450
# 7    Mujer              45-49   1583   1635   1721   1834   1878   2088
# 8    Mujer                50+   1993   1963   2172   2493   2624   2788
# 9    Mujer        No Asignada    584    835    789   1071   1421   1046
# 10  Hombre                15-      0      0      0      0      0      0
# 11  Hombre              15-19    648    537    517    598    428    517
# ...

# %%
years = matri.columns
years = years[2:20].sort_values()
years = list(years)
# new_order = (list(matri.columns)[0:2]) + years
# matri = matri.reindex(columns=new_order)
# matri
years
# Out:
# ['2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018']

# %%
# matri.to_csv("matrimonios_rd.csv", index=False)

# %%
import matplotlib.lines as mlines

# %%
for y in years:
    matri[y] = matri[y].astype(float)

# %%
cb_dark_blue = (0/255, 107/255, 164/255)
cb_orange = (255/255, 128/255, 14/255)
fig = plt.figure(figsize=(10,30))
for sp in range(1,9):
    ax = fig.add_subplot(10,3,sp)
    ax.plot(matri.iloc[sp,2:20], c=cb_orange, label='Women', linewidth=3)
    ax.plot(matri.iloc[sp+10,2:20], c=cb_dark_blue, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom = False, top = False, left = False, right = False, labelbottom=True)
#     ax.set_yticks([matri.iloc[[sp,sp+10], 2:20].min(axis=1).min(),matri.iloc[[sp, sp+10], 2:20].max(axis=1).max()])
    ax.set_xticks(["2001", "2018"])
    ax.set_yticks([])
    ax.set_xticklabels(["2001", "2018"], size=10,alpha=0.6)
#     ax.set_xlim(1968, 2011)
#     ax.set_ylim(0,100)
    ax.set_title(matri["Edad"][sp], y=-0.17)
    if sp < 4:
        ax.tick_params(labelbottom=True, size=5)

#         ax.text("2001", 80, 'Men')
#         ax.text("2001", 15, 'Women')
    if sp > 6:
#         ax.text(2005, 87, 'Men')
#         ax.text(2003, 8, 'Women')
#         ax.set_xticks(["2001", "2018"])
        ax.tick_params(labelbottom=True, size=5)
ax = fig.add_subplot(10,3,9)
ax.plot(0, c=cb_orange, label='Mujeres', linewidth=3)
ax.plot(0, c=cb_dark_blue, label='Hombres', linewidth=3)
for key,spine in ax.spines.items():
    spine.set_visible(False)
ax.tick_params(bottom = False, top = False, left = False, right = False, labelbottom=False)
ax.set_yticks([])


plt.legend(loc="upper left", prop={'size': 10}, frameon=False)
# plt.show()
plt.savefig('gender-diff-year-ig.png', dpi=72, bbox_inches='tight')

# %%
cb_dark_blue = (0/255, 107/255, 164/255)
cb_orange = (255/255, 128/255, 14/255)
fig = plt.figure(figsize=(15,30))
for sp in range(1,9):
    ax = fig.add_subplot(10,3,sp)
    ax.plot(matri.iloc[sp,2:20], c=cb_orange, label='Women', linewidth=3)
    ax.plot(matri.iloc[sp+10,2:20], c=cb_dark_blue, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)
    ax.tick_params(bottom = False, top = False, left = False, right = False, labelbottom=True)
#     ax.set_yticks([matri.iloc[[sp,sp+10], 2:20].min(axis=1).min(),matri.iloc[[sp, sp+10], 2:20].max(axis=1).max()])
    ax.set_xticks(["2001", "2018"])
    ax.set_yticks([])
    ax.set_xticklabels(["2001", "2018"], size=10,alpha=0.6)
#     ax.set_xlim(1968, 2011)
#     ax.set_ylim(0,100)
    ax.set_title(matri["Edad"][sp], y=-0.17)
#     if sp < 4:
#         ax.tick_params(labelbottom=True, size=5)

#         ax.text("2001", 80, 'Men')
#         ax.text("2001", 15, 'Women')
#     if sp > 6:
#         ax.text(2005, 87, 'Men')
#         ax.text(2003, 8, 'Women')
#         ax.set_xticks(["2001", "2018"])
#         ax.tick_params(labelbottom=True, size=5)
ax = fig.add_subplot(10,3,9)
ax.plot(0, c=cb_orange, label='Mujeres', linewidth=3)
ax.plot(0, c=cb_dark_blue, label='Hombres', linewidth=3)
for key,spine in ax.spines.items():
    spine.set_visible(False)
ax.tick_params(bottom = False, top = False, left = False, right = False, labelbottom=False)

ax.set_yticks([])
plt.legend(loc="upper left", prop={'size': 10}, frameon=False)


# plt.legend(loc="upper left")
# # plt.show()
plt.savefig('gender-diff-year-tw.png', dpi=72, bbox_inches='tight')

# %%
# matri["Promedio"] = round(matri.iloc[:,2:20].mean(axis=1),2)
# matri["Total"] = matri.iloc[:,2:20].sum(axis=1)
# matri = matri.append(round(matri.iloc[0:10,2:].sum(axis=0),2), ignore_index=True)
# matri = matri.append(round(matri.iloc[0:10,2:].sum(axis=0),2)*2, ignore_index=True)
# matri["Edad"][20] = "Total Matrimonios"
# matri["Edad"][21] = "Total Personas"
# matri

# %%
matri_heatmap = pd.read_csv("matri_heatmap.csv")
matri_heatmap
# Out:
#           Edades    Total  15-  15-19  20-24  25-29  30-34  35-39  40-44  \
# 0          Total      NaN    0    389   5753  10124   7851   6413   5213
# 1            15-      0.0    0      0      0      0      0      0      0
# 2          15-19   2202.0    0    169   1099    600    185     73     29
# 3          20-24   9423.0    0    151   2985   3576   1380    581    288
# 4          25-29  10570.0    0     42   1005   3750   2723   1332    704
# 5          30-34   7355.0    0     16    333   1142   1919   1737    918
# 6          35-39   6120.0    0      6    164    492    823   1426   1285
# 7          40-44   4922.0    0      2     84    283    421    635   1047
# 8          45-49   3756.0    0      1     48    150    196    336    519
# 9            50+   5565.0    0      1     25     91    180    282    416
# 10  No declarada    144.0    0      1     10     40     24     11      7
#
#     45-49   50+  N/A
# 0    4517  9702   95
# 1       0     0    0
# 2      23    24    0
# ...

# %%
heat_val = []
temp_list = []
for i in range(len(ages)):
    for j in range(len(ages)):
        temp = (heat_data[i,j])
#         temp = round((heat_data[i,j]/women_tots[i])-(heat_data[i,j]/men_tots[i]), 3)*10
        heat_val.append(temp)
heat_val = [heat_val[i:i+8] for i in range(0, len(heat_val), 8)]        
heat_val = pd.DataFrame.from_records(heat_val)

fig, ax = plt.subplots(figsize=(10,20))
im = ax.imshow(heat_data, vmin=100, vmax=3000, cmap="YlGnBu", alpha=0.8, interpolation="mitchell")
#



#all ticks
ax.set_xticks(np.arange(len(ages)))
ax.set_yticks(np.arange(len(ages)))
ax.set_xticklabels(ages, alpha=0.7, size=13, y=1.05)
ax.set_yticklabels(ages, alpha=0.7, size=13)
ax.set_xlabel("Hombres", alpha=0.7, size=15, labelpad=-550)
ax.set_ylabel("Mujeres", alpha=0.7, size=15, labelpad=10)
for key,spine in ax.spines.items():
    spine.set_visible(False)
ax.tick_params(bottom = False, top = False, left = False, right = False)

# for i in range(len(ages)):
#     for j in range(len(ages)):
#         text = ax.text(j, i, heat_data[i, j],
#             ha="center", va="center", color="k")
ax.set_title("Relación de casamientos por edad y género", y=-0.06, size=17)
cbar = fig.colorbar(im, fraction=0.046, pad=0.04, ticks=[0.39,-0.39])
cbar.outline.set_visible(False)
cbar.ax.set_yticklabels(['Más Hombres', "Más Mujeres"], size=12, rotation=45)
cbar.drawedges = False
cbar.spacing = "proportional"
fig.tight_layout()
plt.savefig('matri_heatmap.png', dpi=72, bbox_inches='tight')

# %%
# Combine colormaps
colors1 = plt.cm.Oranges_r(np.linspace(0.3, 1, 256))
colors2 = plt.cm.Blues(np.linspace(0, 1, 256))

# combine them and build a new colormap
colors = np.vstack((colors1, colors2))
mymap = mcolors.LinearSegmentedColormap.from_list('my_colormap', colors)

# %%
ages = list(matri_heatmap.columns[3:11])
heat_data = matri_heatmap.iloc[2:,3:].astype(int).values
women_tots = matri_heatmap.iloc[2:10,1].sum()
men_tots = matri_heatmap.iloc[0,3:11].sum()
women_age_tots = list(matri_heatmap.iloc[2:10,1])
men_age_tots = list(matri_heatmap.iloc[0,3:11])

# %%
heat_val = []
temp_list = []
for i in range(len(ages)):
    for j in range(len(ages)):
        temp = round((heat_data[i,j]/women_age_tots[i])-(heat_data[i,j]/men_age_tots[i]), 3)*5
#         temp = round((heat_data[i,j]/women_tots[i])-(heat_data[i,j]/men_tots[i]), 3)*10
        heat_val.append(temp)
heat_val = [heat_val[i:i+8] for i in range(0, len(heat_val), 8)]        
heat_val = pd.DataFrame.from_records(heat_val)

fig, ax = plt.subplots(figsize=(10,20))
im = ax.imshow(heat_val, vmin=-0.5, vmax=0.4, cmap=mymap, alpha=0.8, interpolation="mitchell")


#all ticks
ax.set_xticks(np.arange(len(ages)))
ax.set_yticks(np.arange(len(ages)))
ax.set_xticklabels(ages, alpha=0.7, size=13, y=1.05)
ax.set_yticklabels(ages, alpha=0.7, size=13)
ax.set_xlabel("Hombres", alpha=0.7, size=15, labelpad=-550)
ax.set_ylabel("Mujeres", alpha=0.7, size=15, labelpad=10)
for key,spine in ax.spines.items():
    spine.set_visible(False)
ax.tick_params(bottom = False, top = False, left = False, right = False)

# for i in range(len(ages)):
#     for j in range(len(ages)):
#         text = ax.text(j, i, heat_data[i, j],
#             ha="center", va="center", color="k")
ax.set_title("Relación de casamientos por edad y género", y=-0.06, size=17)
cbar = fig.colorbar(im, fraction=0.0456, pad=0.04, ticks=[0.39,0,-0.39], drawedges=False)
cbar.outline.set_visible(False)
cbar.ax.set_yticklabels(['Más Hombres', "Similares", "Más Mujeres"], size=12, rotation=45)

fig.tight_layout()
plt.savefig('matri_heatmap.png', dpi=72, bbox_inches='tight')

# %%
heat_val = []
temp_list = []
for i in range(len(ages)):
    for j in range(len(ages)):
#         temp = round((heat_data[i,j]/women_tots[i])-(heat_data[i,j]/men_tots[i]), 3)*10
        temp = round(heat_data[i,j]/men_age_tots[i]*100, 1)
        heat_val.append(temp)
heat_val = [heat_val[i:i+8] for i in range(0, len(heat_val), 8)] 
heat_val = np.array(heat_val)
# heat_val = pd.DataFrame.from_records(heat_val)

fig, ax = plt.subplots(figsize=(10,20))
im = ax.imshow(heat_val, vmin=0, vmax=30, cmap="Oranges", alpha=0.8, interpolation="lanczos")


#all ticks
ax.set_xticks(np.arange(len(ages)))
ax.set_yticks(np.arange(len(ages)))
ax.set_xticklabels(ages, alpha=0.7, size=13, y=1.05)
ax.set_yticklabels(ages, alpha=0.7, size=13)
ax.set_xlabel("Hombres", alpha=0.7, size=15, labelpad=-600)
ax.set_ylabel("Mujeres", alpha=0.7, size=15, labelpad=10)
for key,spine in ax.spines.items():
    spine.set_visible(False)
ax.tick_params(bottom = False, top = False, left = False, right = False)

# for i in range(len(ages)):
#     for j in range(len(ages)):
#         text = ax.text(j, i, round((heat_data[i,j]/women_age_tots[i])*100, 1),
#             ha="center", va="center", color="k")
ax.set_title("¿A qué edad se casan las mujeres y con quién?", y=-0.06, size=17)
cbar = fig.colorbar(im, fraction=0.046, pad=0.04, ticks=[18])
cbar.outline.set_visible(False)
cbar.ax.set_yticklabels(["Mayor tasa de matrimonio"], size=12, rotation=90)
cbar.drawedges = False
cbar.spacing = "proportional"
fig.tight_layout()
plt.savefig('female_matri_lanczos.png', dpi=72, bbox_inches='tight')

# %%
heat_val = []
temp_list = []
for i in range(len(ages)):
    for j in range(len(ages)):
#         temp = round((heat_data[i,j]/women_tots[i])-(heat_data[i,j]/men_tots[i]), 3)*10
        temp = round(heat_data[j,i]/men_age_tots[i]*100, 1)
        heat_val.append(temp)
heat_val = [heat_val[i:i+8] for i in range(0, len(heat_val), 8)] 
heat_val = np.array(heat_val)
# heat_val = pd.DataFrame.from_records(heat_val)

fig, ax = plt.subplots(figsize=(10,20))
im = ax.imshow(heat_val, vmin=-0, vmax=25, cmap="Blues", alpha=0.8, interpolation="lanczos")


#all ticks
ax.set_xticks(np.arange(len(ages)))
ax.set_yticks(np.arange(len(ages)))
ax.set_xticklabels(ages, alpha=0.7, size=13, y=1.05)
ax.set_yticklabels(ages, alpha=0.7, size=13)
ax.set_xlabel("Mujeres", alpha=0.7, size=15, labelpad=-600)
ax.set_ylabel("Hombres", alpha=0.7, size=15, labelpad=10)
for key,spine in ax.spines.items():
    spine.set_visible(False)
ax.tick_params(bottom = False, top = False, left = False, right = False)

# for i in range(len(ages)):
#     for j in range(len(ages)):
#         text = ax.text(j, i, round((heat_data[j,i]/men_age_tots[i])*100, 1),
#             ha="center", va="center", color="k")
ax.set_title("¿A qué edad se casan los hombres y con quién?", y=-0.06, size=17)
cbar = fig.colorbar(im, fraction=0.046, pad=0.04, ticks=[15])
cbar.outline.set_visible(False)
cbar.ax.set_yticklabels(["Mayor tasa de matrimonio"], size=12, rotation=90)
# cbar.set_ticks(
fig.tight_layout()
plt.savefig('male_matri_lanczos.png', dpi=72, bbox_inches='tight')

# %%
reduced_matri.to_csv("reduced_matrimonios.csv", index=False)

# %%
reduced_matri = reduced_matri.drop(columns=["Total Matrimonios","Total Personas" ])

# %%
reduced_matri
# Out:
# Edad     15-    15-19    20-24    25-29    30-34    35-39    40-44    45-49  \
# Género
# Hombre  0.00   464.78  5496.67  9201.56  7591.83  5758.72  4448.11  3322.78
# Mujer   0.22  2397.83  9182.28  9585.67  6992.33  4938.61  3596.78  2481.44
#
# Edad        50+  No Asignada
# Género
# Hombre  6348.28       504.44
# Mujer   3293.67       668.33

# %%
reduced_matri = reduced_matri.drop(reduced_matri.index[0])

# %%
for a in range(0,2):
    for b in range(0,10):
        matri.iloc[a][b] = float(matri.iloc[a][b])

# %%
reducol = reduced_matri.columns

# %%
type(reduced_matri["15 - 19"][1])
# Out:
# numpy.float64

# %%
reduced_matri = pd.read_csv("reduced_matrimonios.csv", index_col=0)
reduced_matri
# Out:
#          15-  15 - 19  20 - 24  25 - 29  30 - 34  35 - 39  40 - 44  45 - 49  \
# Genero
# Hombre  0.00   464.78  5496.67  9201.56  7591.83  5758.72  4448.11  3322.78
# Mujer   0.22  2397.83  9182.28  9585.67  6992.33  4938.61  3596.78  2481.44
#
#             50+  No Asignada
# Genero
# Hombre  6348.28       504.44
# Mujer   3293.67       668.33

# %%
diff = (reduced_matri.loc["Hombre"][0:9]-reduced_matri.loc["Mujer"][0:9]).astype(int)
ticks = reduced_matri.columns[0:-1]
mask1 = diff <= 0
mask2 = diff > 0

# %%
fig, ax = plt.subplots(figsize=(16,9))
ax.plot(reduced_matri.loc["Hombre"][1:9], c=cb_dark_blue, label='Hombres', linewidth=3)
ax.plot(reduced_matri.loc["Mujer"][1:9], c=cb_orange, label='Mujeres', linewidth=3)
ax.tick_params(bottom = False, top = False, left = False, right = False, labelbottom=True)
ax.set_yticks([])
ax.set_xticklabels(labels=ticks, size=15,alpha=0.6)
for key,spine in ax.spines.items():
    spine.set_visible(False)
plt.legend(loc="upper left", prop={'size': 15}, frameon=False)
plt.savefig('gender-diff-age-lines.png',dpi=72, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(16,9))
ax.fill_between(ages, reduced_matri.loc["Hombre"][1:9],  label='Hombres', linewidth=3, alpha=0.5)
ax.fill_between(ages, reduced_matri.loc["Mujer"][1:9], label='Mujeres', linewidth=3, alpha=0.5)
ax.tick_params(bottom = False, top = False, left = False, right = False, labelbottom=True)
ax.set_yticks([])
ax.set_xticklabels(labels=ticks[1:], size=15,alpha=0.6)
for key,spine in ax.spines.items():
    spine.set_visible(False)
plt.legend(loc="upper left", prop={'size': 15}, frameon=False)
plt.savefig('gender-diff-age-area.png',dpi=72, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(16,9))
ax.bar(ticks[mask1], diff[mask1], width=0.7, align="center", label='Mujeres', color=cb_orange, alpha=0.8)
ax.bar(ticks[mask2], diff[mask2], width=0.7, align="center", label='Hombres', color=cb_dark_blue, alpha=0.8)
ax.tick_params(bottom = False, top = False, left = False, right = False, labelbottom=True)
ax.set_yticks([])
ax.set_xticklabels(labels=ticks, size=15,alpha=0.6)
for key,spine in ax.spines.items():
    spine.set_visible(False)
for a in range(0,9):
    plt.text(a-0.2, diff[a]+100 if diff[a] > 0 else diff[a]-300, s=diff[a] if diff[a] > 0 else diff[a]*-1, size=15)

plt.legend(loc="upper left", prop={'size': 15}, frameon=False)
plt.savefig('gender-diff-age.png',dpi=72, bbox_inches='tight')
